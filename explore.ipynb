# %%
import pandas as pd

# %%
from pathlib import Path

part_path = Path("part-1")
part_path.mkdir(exist_ok=True)

raw_path = Path(f"{part_path}/raw")
raw_path.mkdir(exist_ok=True)

processed_path = Path(f"{part_path}/processed")
processed_path.mkdir(exist_ok=True)

submission_path = Path(f"{part_path}/submission")
submission_path.mkdir(exist_ok=True)

# %%
df_train = pd.read_csv(f"{processed_path}/train-embeddings.csv")
df_test = pd.read_csv(f"{processed_path}/test-embeddings.csv")

# %%
df_train.head()
# Out:
#    id                                   project_a                project_b  \
# 0   2  prettier-solidity/prettier-plugin-solidity  nomicfoundation/hardhat
# 1   3  prettier-solidity/prettier-plugin-solidity           consensys/teku
# 2   4  prettier-solidity/prettier-plugin-solidity        ethereum/solidity
# 3   5  prettier-solidity/prettier-plugin-solidity   ethereum/remix-project
# 4   6  prettier-solidity/prettier-plugin-solidity     ethereum/go-ethereum
#
#    weight_a  weight_b                                        description  \
# 0  0.101669  0.898331  A Prettier plugin for automatically formatting...
# 1  0.669446  0.330554  A Prettier plugin for automatically formatting...
# 2  0.449022  0.550978  A Prettier plugin for automatically formatting...
# 3  0.498396  0.501604  A Prettier plugin for automatically formatting...
# 4  0.272503  0.727497  A Prettier plugin for automatically formatting...
#
#              created_at            updated_at  size  has_wiki  ...  \
# 0  2018-05-15T15:12:02Z  2025-02-04T11:20:22Z  4658      True  ...
# 1  2018-05-15T15:12:02Z  2025-02-04T11:20:22Z  4658      True  ...
# 2  2018-05-15T15:12:02Z  2025-02-04T11:20:22Z  4658      True  ...
# 3  2018-05-15T15:12:02Z  2025-02-04T11:20:22Z  4658      True  ...
# 4  2018-05-15T15:12:02Z  2025-02-04T11:20:22Z  4658      True  ...
#
#    num_dependents_ratio  v_index_ratio  stars_intersection_v_index  \
# 0              0.493794            0.0                    0.000731
# 1              1.000000            0.0                    0.000731
# 2              1.000000            0.0                    0.000731
# 3              0.982363            0.0                    0.000731
# 4              0.735799            0.0                    0.000731
#
#    stars_b_intersection_v_index_b  stars_ratio_intersection_v_index_ratio  \
# 0                        0.007484                            8.898357e-08
# 1                        0.000692                            5.137034e-07
# 2                        0.023833                            2.975900e-08
# 3                        0.002575                            2.211131e-07
# 4                   144825.048275                            1.491654e-08
#
#                                            embedding cosine_similarity  \
# 0  [-0.042093899101018906, -0.024247141554951668,...          0.210336
# 1  [-0.042093899101018906, -0.024247141554951668,...          0.210336
# 2  [-0.042093899101018906, -0.024247141554951668,...          0.210336
# 3  [-0.042093899101018906, -0.024247141554951668,...          0.210336
# 4  [-0.042093899101018906, -0.024247141554951668,...          0.210336
#
#                                          embedding_b  cosine_similarity_b  \
# 0  [-0.02257283218204975, -0.009097057394683361, ...             0.431414
# 1  [0.005951829720288515, 0.007955850102007389, 0...             0.350827
# 2  [0.011512658558785915, -0.009468786418437958, ...             0.411842
# 3  [-0.03321365639567375, -0.0014297625748440623,...             0.386724
# 4  [0.00618064496666193, 0.03895679488778114, 0.0...             0.483286
#
#    cosine_ratio
# 0      0.327754
# 1      0.374821
# 2      0.338064
# 3      0.352286
# 4      0.303243
#
# [5 rows x 86 columns]
